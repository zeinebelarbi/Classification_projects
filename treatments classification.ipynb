# %% [markdown]
# # Importing required Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %% [markdown]
# # Dataset Loading and Reading

# %%
df = pd.read_csv('treatment_set.csv')
df.head()
# Out:
#    HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  MCHC  \
# 0         33.8          11.1         4.18        4.6          150  26.6  32.8
# 1         44.6          14.0         6.86        6.3          232  20.4  31.4
# 2         42.9          14.0         4.57        6.2          336  30.6  32.6
# 3         41.9          14.4         4.67        3.5          276  30.8  34.4
# 4         40.6          13.3         4.85       14.9          711  27.4  32.8
#
#     MCV  AGE SEX  SOURCE
# 0  80.9   33   F       1
# 1  65.0   36   M       0
# 2  93.9   70   F       0
# 3  89.7   18   F       0
# 4  83.7   36   M       0

# %% [markdown]
# # Dataset Analyzing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3309 entries, 0 to 3308
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HAEMATOCRIT   3309 non-null   float64
#  1   HAEMOGLOBINS  3309 non-null   float64
#  2   ERYTHROCYTE   3309 non-null   float64
#  3   LEUCOCYTE     3309 non-null   float64
#  4   THROMBOCYTE   3309 non-null   int64
#  5   MCH           3309 non-null   float64
#  6   MCHC          3309 non-null   float64
#  7   MCV           3309 non-null   float64
#  8   AGE           3309 non-null   int64
#  9   SEX           3309 non-null   object
#  10  SOURCE        3309 non-null   int64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 284.5+ KB

# %% [markdown]
# # Dataset description

# %%
df.describe()
# Out:
#        HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE    LEUCOCYTE  THROMBOCYTE  \
# count  3309.000000   3309.000000  3309.000000  3309.000000  3309.000000
# mean     38.226111     12.749350     4.544802     8.715533   258.893019
# std       5.971943      2.084325     0.784510     4.991299   112.676139
# min      13.700000      3.800000     1.480000     1.100000    10.000000
# 25%      34.300000     11.400000     4.040000     5.700000   191.000000
# 50%      38.700000     12.900000     4.580000     7.600000   257.000000
# 75%      42.500000     14.200000     5.060000    10.300000   322.000000
# max      69.000000     18.900000     7.860000    76.600000  1121.000000
#
#                MCH         MCHC          MCV          AGE       SOURCE
# count  3309.000000  3309.000000  3309.000000  3309.000000  3309.000000
# mean     28.230039    33.336476    84.611333    46.644303     0.398005
# std       2.696520     1.247055     6.916079    21.874106     0.489561
# ...

# %%
df.describe(include ='O')
# Out:
#          SEX
# count   3309
# unique     2
# top        M
# freq    1743

# %% [markdown]
# # Total no. of Rows and Columns in Dataset

# %%
df.shape
# Out:
# (3309, 11)

# %% [markdown]
# # Unique Values count

# %%
df.nunique()
# Out:
# HAEMATOCRIT     314
# HAEMOGLOBINS    128
# ERYTHROCYTE     406
# LEUCOCYTE       255
# THROMBOCYTE     525
# MCH             177
# MCHC            101
# MCV             390
# AGE              95
# SEX               2
# SOURCE            2
# dtype: int64

# %%
df.	SEX.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.MCH.unique()
# Out:
# array([26.6, 20.4, 30.6, 30.8, 27.4, 28.4, 23.9, 28.1, 29.4, 28.5, 28.9,
#        26.7, 29. , 19.1, 31.3, 32.5, 23.7, 20. , 30.3, 27.6, 29.3, 21.6,
#        28.7, 25.6, 29.2, 27.8, 29.7, 27.7, 27.3, 26.5, 21.8, 27.5, 24.3,
#        28. , 28.2, 31.5, 29.6, 26.4, 33.4, 30.1, 35.4, 31.4, 30. , 29.5,
#        28.6, 27.9, 33.2, 25.2, 31.6, 29.8, 22. , 30.4, 31.7, 28.8, 28.3,
#        25.8, 22.5, 27.2, 29.9, 27. , 30.5, 24.4, 30.9, 25.3, 23.2, 25.4,
#        30.2, 29.1, 25.5, 34.2, 24.1, 31.8, 25.1, 30.7, 22.2, 34.8, 19. ,
#        27.1, 26.9, 24.6, 32.1, 31.9, 24.9, 31. , 35.7, 33.1, 32.3, 23.4,
#        21.5, 25.9, 17. , 20.8, 19.7, 25.7, 32.4, 23.1, 26.2, 26.1, 23.8,
#        20.2, 15.8, 26.3, 32.9, 31.1, 22.7, 26. , 21.1, 31.2, 33.9, 23.6,
#        32.6, 16.8, 24.8, 32. , 24.7, 37.8, 17.5, 32.8, 25. , 19.5, 21.2,
#        26.8, 21. , 23.3, 22.3, 20.1, 17.1, 34. , 22.6, 18. , 21.9, 36.6,
#        23.5, 40.8, 33.3, 24.5, 22.1, 32.7, 33. , 18.9, 20.6, 23. , 20.3,
# ...

# %% [markdown]
#  # The difference between unique and nunique  :
# The unique () function returns all the unique values of a list/column in the form of an array,yet, The nunique () function returns the number of all unique values.

# %% [markdown]
# # Missing Data Checking
# Testing if there are some missing values : no missing values in this case

# %%
df.isnull().sum()
# Out:
# HAEMATOCRIT     0
# HAEMOGLOBINS    0
# ERYTHROCYTE     0
# LEUCOCYTE       0
# THROMBOCYTE     0
# MCH             0
# MCHC            0
# MCV             0
# AGE             0
# SEX             0
# SOURCE          0
# dtype: int64

# %% [markdown]
# # Duplicated Data Checking
# Testing if there are duplicated rows : no duplicated rows in this case

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Outliers checking
# Boxplot

# %%
sns.set(style="darkgrid")
ax =sns.boxplot(data=df['AGE'],orient='v')

# %%
ax =sns.boxplot(data=df['MCHC'],orient='v')

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Scatterplot for quantitaves features

# %%
sns.pairplot(df, hue ='MCH')

# %% [markdown]
# #Histogramme

# %%
df.columns
# Out:
# Index(['HAEMATOCRIT', 'HAEMOGLOBINS', 'ERYTHROCYTE', 'LEUCOCYTE',
#        'THROMBOCYTE', 'MCH', 'MCHC', 'MCV', 'AGE', 'SEX', 'SOURCE'],
#       dtype='object')

# %%
plt.hist(df.MCH, label='MCH')
plt.title('Répartition des classes')
plt.legend(loc='best')

# %% [markdown]
# # Heatmap

# %%
f, ax =plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(method ='pearson'),annot =True)
# Out:
# <AxesSubplot:>

# %%
df.drop(columns=['AGE'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  MCHC  \
# 0         33.8          11.1         4.18        4.6          150  26.6  32.8
# 1         44.6          14.0         6.86        6.3          232  20.4  31.4
# 2         42.9          14.0         4.57        6.2          336  30.6  32.6
# 3         41.9          14.4         4.67        3.5          276  30.8  34.4
# 4         40.6          13.3         4.85       14.9          711  27.4  32.8
#
#     MCV SEX  SOURCE
# 0  80.9   F       1
# 1  65.0   M       0
# 2  93.9   F       0
# 3  89.7   F       0
# 4  83.7   M       0

# %% [markdown]
# # Converting categorical data to numerical data

# %%
df1=df.copy()
df1.head()
# Out:
#    HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  MCHC  \
# 0         33.8          11.1         4.18        4.6          150  26.6  32.8
# 1         44.6          14.0         6.86        6.3          232  20.4  31.4
# 2         42.9          14.0         4.57        6.2          336  30.6  32.6
# 3         41.9          14.4         4.67        3.5          276  30.8  34.4
# 4         40.6          13.3         4.85       14.9          711  27.4  32.8
#
#     MCV  SEX  SOURCE
# 0  80.9    0       1
# 1  65.0    1       0
# 2  93.9    0       0
# 3  89.7    0       0
# 4  83.7    1       0

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df1.SEX= labelencoder.fit_transform(df.SEX)
df1.head()
# Out:
#    HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  MCHC  \
# 0         33.8          11.1         4.18        4.6          150  26.6  32.8
# 1         44.6          14.0         6.86        6.3          232  20.4  31.4
# 2         42.9          14.0         4.57        6.2          336  30.6  32.6
# 3         41.9          14.4         4.67        3.5          276  30.8  34.4
# 4         40.6          13.3         4.85       14.9          711  27.4  32.8
#
#     MCV  SEX  SOURCE
# 0  80.9    0       1
# 1  65.0    1       0
# 2  93.9    0       0
# 3  89.7    0       0
# 4  83.7    1       0

# %%
df2=df.copy()
df2.head()
# Out:
#    HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  MCHC  \
# 0         33.8          11.1         4.18        4.6          150  26.6  32.8
# 1         44.6          14.0         6.86        6.3          232  20.4  31.4
# 2         42.9          14.0         4.57        6.2          336  30.6  32.6
# 3         41.9          14.4         4.67        3.5          276  30.8  34.4
# 4         40.6          13.3         4.85       14.9          711  27.4  32.8
#
#     MCV  SEX  SOURCE
# 0  80.9    0       1
# 1  65.0    1       0
# 2  93.9    0       0
# 3  89.7    0       0
# 4  83.7    1       0

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df2.MCH= labelencoder.fit_transform(df.MCH)
df2.head()
# Out:
#    HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE  MCH  MCHC  \
# 0         33.8          11.1         4.18        4.6          150   94  32.8
# 1         44.6          14.0         6.86        6.3          232   35  31.4
# 2         42.9          14.0         4.57        6.2          336  134  32.6
# 3         41.9          14.4         4.67        3.5          276  136  34.4
# 4         40.6          13.3         4.85       14.9          711  102  32.8
#
#     MCV  SEX  SOURCE
# 0  80.9    0       1
# 1  65.0    1       0
# 2  93.9    0       0
# 3  89.7    0       0
# 4  83.7    1       0

# %% [markdown]
# # Creating Feature columns and Target column

# %%
features_cols=['SEX']
X=df1[features_cols]

# %%
X.head(2)
# Out:
#    SEX
# 0    0
# 1    1

# %% [markdown]
# # Creating training and testing dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, shuffle=True, random_state=1)

# %% [markdown]
# # Data Standardisation

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_sc =scaler.fit_transform(X_train)
X_test_sc =scaler.transform(X_test)

# %%
X_train.head()
# Out:
#       SEX
# 573     1
# 2074    1
# 2150    1
# 1395    0
# 233     1

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors = 3 )
knn.fit(X_train_sc,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred_knn =knn.predict(X_test_sc)

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(knn, X_test_sc, y_test, cmap='Blues')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.metrics import f1_score
print('F1 score knn :', f1_score(y_test,y_pred_knn,average=None))
# Out:
# F1 score knn : [0.55172414 0.47316539]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.49      0.55       609
#            1       0.41      0.56      0.47       384
#
#     accuracy                           0.52       993
#    macro avg       0.52      0.52      0.51       993
# weighted avg       0.55      0.52      0.52       993

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier (n_estimators=100)
rf.fit(X_train,y_train)
y_pred_rf = rf.predict(X_test)

# %%
print(classification_report(y_test,y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       609
#            1       0.00      0.00      0.00       384
#
#     accuracy                           0.61       993
#    macro avg       0.31      0.50      0.38       993
# weighted avg       0.38      0.61      0.47       993
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
df.columns
# Out:
# Index(['HAEMATOCRIT', 'HAEMOGLOBINS', 'ERYTHROCYTE', 'LEUCOCYTE',
#        'THROMBOCYTE', 'MCH', 'MCHC', 'MCV', 'SEX', 'SOURCE'],
#       dtype='object')

# %%
importances= rf.features_importances_
importances
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [97], in <cell line: 1>()
# ----> 1 importances= rf.features_importances_
#       2 importances
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'features_importances_'

# %%
import numpy as np 
sorted_idx=np.argsort(importances)
sorted_idx
# Out:
# array([0], dtype=int64)

# %%
features =df.columns[sorted_idx]

# %%
padding=np.arange(X_train.size/len(X_train))
plt.barh(padding,importances[sorted_idx],align='center')
plt.yticks(padding,features)
plt.xlabel("Relative importance")
plt.title("Variable importance")
# Out:
# Text(0.5, 1.0, 'Variable importance')
